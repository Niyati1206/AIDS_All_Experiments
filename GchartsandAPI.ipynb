# %%
from IPython.core.display import HTML
import pandas as pd

# %%
df = pd.read_csv('DMart.csv')

# %%
chart_code = """
<!DOCTYPE html>
<html>
<head>
  <script type="text/javascript" src="https://www.gstatic.com/charts/loader.js"></script>
  <script type="text/javascript">
    google.charts.load('current', {'packages':['corechart']});
    google.charts.setOnLoadCallback(drawChart);

    function drawChart() {
      var data = google.visualization.arrayToDataTable([
        ['Category', 'Quantity'],
        ['Personal Care',1237],
        ['Packaged Food', 1125],
        ['Home & Kitchen', 880],
        ['Dairy & Beverages', 	429],
        ['Specials', 	187],
        ['Clothing & Accessories', 	97],
        ['Fruits & Vegetables', 78],
        ['School Supplies', 69],
        ['Appliances', 53],
        ['Beauty & Cosmetics', 46],
        ['Raincoat', 33],
        ['DMart Grocery', 31],
        ['Plant Container', 23],
        ['Tableware', 18],
        ['Backpacks', 13],
        ['Zebronics', 5],
        ['Motorbike Helmets', 4],
        ['Baby & Kids', 4],
        ['Geep', 3],
        ['Kitchen Aprons', 3],
        ['Butterfly', 2],
        ['Computer Accessories', 2],
        ['Joyo Plastics', 2],
        ['Pigeon', 1],
        ['Syska', 1],
        ['Water Purifiers & Accessories', 	1],
        ['Wonderchef', 	1],
        ['Smartwatches', 	1],
      ]);

      var options = {
        title: 'Product Quantity by Category',
        is3D: true,
      };

      var chart = new google.visualization.PieChart(document.getElementById('piechart'));

      chart.draw(data, options);
    }
  </script>
</head>
<body>
  <div id="piechart" style="width: 900px; height: 500px;"></div>
</body>
</html>
"""
display(HTML(chart_code))
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#   <script type="text/javascript" src="https://www.gstatic.com/charts/loader.js"></script>
#   <script type="text/javascript">
#     google.charts.load('current', {'packages':['corechart']});
#     google.charts.setOnLoadCallback(drawChart);
#
#     function drawChart() {
#       var data = google.visualization.arrayToDataTable([
#         ['Category', 'Quantity'],
#         ['Personal Care',1237],
#         ['Packaged Food', 1125],
#         ['Home & Kitchen', 880],
#         ['Dairy & Beverages', 	429],
#         ['Specials', 	187],
#         ['Clothing & Accessories', 	97],
#         ['Fruits & Vegetables', 78],
#         ['School Supplies', 69],
#         ['Appliances', 53],
#         ['Beauty & Cosmetics', 46],
#         ['Raincoat', 33],
#         ['DMart Grocery', 31],
#         ['Plant Container', 23],
#         ['Tableware', 18],
#         ['Backpacks', 13],
#         ['Zebronics', 5],
#         ['Motorbike Helmets', 4],
# ...

# %%
df['Category'].value_counts()
# Out:
# Category
# Personal Care                    1234
# Packaged Food                    1125
# Home & Kitchen                    880
# Grocery                           840
# Dairy & Beverages                 429
# Specials                          187
# Clothing & Accessories             97
# Fruits & Vegetables                78
# School Supplies                    69
# Appliances                         53
# Beauty & Cosmetics                 46
# Raincoat                           33
# DMart Grocery                      31
# Plant Container                    23
# Tableware                          18
# Backpacks                          13
# Zebronics                           5
# Motorbike Helmets                   4
# Baby & Kids                         4
# Geep                                3
# Kitchen Aprons                      3
# Butterfly                           2
# Computer Accessories                2
# Joyo Plastics                       2
# ...

# %%
chart_code = """
<!DOCTYPE html>
<html>
<head>
  <script type="text/javascript" src="https://www.gstatic.com/charts/loader.js"></script>
  <script type="text/javascript">
    google.charts.load('current', {'packages':['corechart']});
    google.charts.setOnLoadCallback(drawChart);

    function drawChart() {
      var data = google.visualization.arrayToDataTable([
        ['Brand', 'Price'],
        """

for index, row in df.groupby('Brand')['Price'].sum().sort_values(ascending=False).head(10).items():
  chart_code += f"['{index}', {row}],\n"


chart_code += """
      ]);

      var options = {
        title: 'Average Price by Brand (Top 10)',
        hAxis: {title: 'Brand'},
        vAxis: {title: 'Average Price'},
        legend: 'none'
      };

      var chart = new google.visualization.ColumnChart(document.getElementById('columnchart'));

      chart.draw(data, options);
    }
  </script>
</head>
<body>
  <div id="columnchart" style="width: 900px; height: 500px;"></div>
</body>
</html>
"""

display(HTML(chart_code))
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#   <script type="text/javascript" src="https://www.gstatic.com/charts/loader.js"></script>
#   <script type="text/javascript">
#     google.charts.load('current', {'packages':['corechart']});
#     google.charts.setOnLoadCallback(drawChart);
#
#     function drawChart() {
#       var data = google.visualization.arrayToDataTable([
#         ['Brand', 'Price'],
#         ['Faces Canada', 35888.0],
# ['Philips', 35289.0],
# ['Bajaj', 34159.0],
# ['Zeel', 30933.0],
# ['Prestige', 30225.0],
# ['Wonderchef', 29700.0],
# ['Crompton Greaves', 25349.0],
# ['Lakme', 24860.0],
# ['Trident', 24182.0],
# ['Usha', 23980.0],
#
#       ]);
#
#       var options = {
#         title: 'Average Price by Brand (Top 10)',
#         hAxis: {title: 'Brand'},
#         vAxis: {title: 'Average Price'},
#         legend: 'none'
#       };
#
#       var chart = new google.visualization.ColumnChart(document.getElementById('columnchart'));
#
#       chart.draw(data, options);
# ...
